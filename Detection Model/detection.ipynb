# %%
# !pip install ultralytics opencv-python

from ultralytics import YOLO
import os
import cv2

print("✅ Libraries loaded")
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# ✅ Libraries loaded

# %%
# Set working directory to your Detection Model folder
os.chdir(r"E:\internship project\Detection Model")

print("✅ Working directory set to:", os.getcwd())
# Out:
# ✅ Working directory set to: E:\internship project\Detection Model

# %%
# Check dataset files exist
base = r"E:\internship project\Detection Model\detection_dataset"

for root, dirs, files in os.walk(base):
    print(root, "->", len(files), "files")
# Out:
# E:\internship project\Detection Model\detection_dataset -> 1 files
# E:\internship project\Detection Model\detection_dataset\images -> 0 files
# E:\internship project\Detection Model\detection_dataset\images\train -> 240 files
# E:\internship project\Detection Model\detection_dataset\images\val -> 53 files
# E:\internship project\Detection Model\detection_dataset\labels -> 0 files
# E:\internship project\Detection Model\detection_dataset\labels\train -> 240 files
# E:\internship project\Detection Model\detection_dataset\labels\val -> 51 files

# %%
# Out:
# ✅ data.yaml created successfully

# %%
model = YOLO("yolov8n.pt")   # use YOLOv8n or yolo11n.pt if you downloaded it
print("✅ Pretrained YOLO loaded")
# Out:
# ...
# ✅ Pretrained YOLO loaded

# %%
results = model.train(
    data="data.yaml",
    epochs=25,
    imgsz=640,
    batch=8
)

print("✅ Training complete")
# Out:
# New https://pypi.org/project/ultralytics/8.3.226 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.221  Python-3.13.5 torch-2.9.0+cpu CPU (AMD Ryzen 5 5600H with Radeon Graphics)
# ...

# %%
from ultralytics import YOLO

trained_model_path = r"E:\internship project\runs\detect\train3\weights\best.pt"
model = YOLO(trained_model_path)

print("✅ Trained model loaded:", trained_model_path)
# Out:
# ✅ Trained model loaded: E:\internship project\runs\detect\train3\weights\best.pt

# %%
metrics = model.val()

print("✅ Validation complete")
print("mAP50-95:", metrics.box.map)
print("mAP50:", metrics.box.map50)
print("mAP75:", metrics.box.map75)
# Out:
# Ultralytics 8.3.221  Python-3.13.5 torch-2.9.0+cpu CPU (AMD Ryzen 5 5600H with Radeon Graphics)
# Model summary (fused): 72 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.20.0 ms, read: 317.7223.9 MB/s, size: 396.6 KB)
# val: Scanning E:\internship project\Detection Model\detection_dataset\labels\val.cache... 51 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 51/51 22.8Kit/s 0.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.4it/s 9.2s4.3ss
#                    all         51        156      0.907      0.855      0.918      0.663
#                   name         49         49      0.893       0.68       0.82      0.573
#                    uid         48         63      0.882      0.952      0.958      0.688
#                address         32         44      0.947      0.932      0.977      0.729
# ...

# %%
test_images = [
    r"E:\internship project\Detection Model\detection_dataset\images\train\1.jpg",
    r"E:\internship project\Detection Model\detection_dataset\images\train\2.jpg",
    r"E:\internship project\Detection Model\detection_dataset\images\train\3.jpg"
]

for img in test_images:
    results = model(img)
    results[0].show()

print("✅ Predictions done")
# Out:
# image 1/1 E:\internship project\Detection Model\detection_dataset\images\train\1.jpg: 512x640 1 name, 1 uid, 95.9ms
# Speed: 6.3ms preprocess, 95.9ms inference, 1.1ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 E:\internship project\Detection Model\detection_dataset\images\train\2.jpg: 512x640 1 uid, 1 address, 86.2ms
# Speed: 5.1ms preprocess, 86.2ms inference, 0.9ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 E:\internship project\Detection Model\detection_dataset\images\train\3.jpg: 640x480 1 uid, 2 addresss, 118.9ms
# Speed: 5.1ms preprocess, 118.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# ✅ Predictions done
