# %%
# !pip install ultralytics opencv-python
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ultralytics import YOLO
import os

# %%
dataset_path = r"E:\internship project\Classification Model\Classification dataset"

for root, dirs, files in os.walk(dataset_path):
    print(root, "->", len(files), "files")
# Out:
# E:\internship project\Classification Model\Classification dataset -> 2 files
# E:\internship project\Classification Model\Classification dataset\train -> 0 files
# E:\internship project\Classification Model\Classification dataset\train\aadhar -> 360 files
# E:\internship project\Classification Model\Classification dataset\train\non_aadhar -> 334 files
# E:\internship project\Classification Model\Classification dataset\val -> 0 files
# E:\internship project\Classification Model\Classification dataset\val\aadhar -> 83 files
# E:\internship project\Classification Model\Classification dataset\val\non_aadhar -> 109 files

# %%
# Load YOLOv8 classification model (you can also use yolo11n-cls.pt if downloaded)
model = YOLO("yolov8n-cls.pt")

# Train the classifier
""" results = model.train(
    data=dataset_path,
    epochs=15,
    imgsz=224,     # 224x224 typical for classification
    batch=8
) """

print("✅ Training complete")
# Out:
# ✅ Training complete

# %%
trained_classifier = r"E:\internship project\runs\classify\train\weights\best.pt"
model = YOLO(trained_classifier)

print("✅ Loaded model:", trained_classifier)
# Out:
# ✅ Loaded model: E:\internship project\runs\classify\train\weights\best.pt

# %%
metrics = model.val()
print("✅ Validation done")
print("Top-1 Accuracy:", metrics.top1)
print("Top-5 Accuracy:", metrics.top5)
# Out:
# Ultralytics 8.3.221  Python-3.13.5 torch-2.9.0+cpu CPU (AMD Ryzen 5 5600H with Radeon Graphics)
# YOLOv8n-cls summary (fused): 30 layers, 1,437,442 parameters, 0 gradients, 3.3 GFLOPs
# train: E:\internship project\Classification Model\Classification dataset\train... found 694 images in 2 classes
# val: E:\internship project\Classification Model\Classification dataset\val... found 192 images in 2 classes
# test: None...
# val: Fast image access  (ping: 0.40.3 ms, read: 25.322.4 MB/s, size: 438.4 KB)
# val: Scanning E:\internship project\Classification Model\Classification dataset\val... 192 images, 0 corrupt: 100% ━━━━━━━━━━━━ 192/192 169.7Kit/s 0.0s
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 12/12 0.6it/s 19.5s1.6s
#                    all      0.995          1
# Speed: 0.0ms preprocess, 13.6ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to E:\internship project\runs\classify\val2
# ✅ Validation done
# Top-1 Accuracy: 0.9947916865348816
# ...

# %%
test_image = r"E:\internship project\Classification Model\Classification dataset\val\aadhar\1.jpg"  # example

results = model(test_image)
results[0].show()
print("✅ Prediction complete")
# Out:
# image 1/1 E:\internship project\Classification Model\Classification dataset\val\aadhar\1.jpg: 224x224 aadhar 1.00, non_aadhar 0.00, 16.7ms
# Speed: 10.0ms preprocess, 16.7ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# ✅ Prediction complete
